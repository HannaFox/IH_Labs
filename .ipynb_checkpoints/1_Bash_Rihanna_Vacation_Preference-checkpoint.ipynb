# %% [markdown]
# Intro to Rihanna's favorite vacation spot

# %% [markdown]
# ## Table of Contents: Rihanna
# 1. [Name](#1.-Name)
# 2. [Pictures](#2.-Pictures)
# 3. [Vacation Style](#3.-Vacation)
#     3.1   [Photo](#3.1-Photo)
#     3.2 [Activities](#3.2-Activities)
#     3.3 [Video](#3.1-MV)

# %% [markdown]
# ## 1. Name

# %%
x = input("Enter name: ")
# Out:
# Enter name: Rihanna

# %% [markdown]
# ## 2. Pictures

# %% [markdown]
# ![alternatvie text](data:image/jpeg;base64,...)

# %% [markdown]
# URL -> Bild:    ![some text](URL-to-image)

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTJSWKZqI_rPUd8fXdvADghJOsBxvraHC9LHA&usqp=CAU)

# %% [markdown]
# ## 3. Vacation

# %% [markdown]
# ### 3.1 Photo

# %% [markdown]
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# ### 3.2 Activities

# %% [markdown]
# - **Barbados**
# - *hometown chilling*
# - <font color="orange" >hanging out at the beach

# %% [markdown]
# bullet points: - text (markdown, run cell)
# bold: **text**
# italic: *text*
# color: <font color="orange" >text

# %% [markdown]
# ### 3.3 MV

# %% [markdown]
# [Rihanna - Love On The Brain MV instead of vacation video](https://www.youtube.com/watch?v=zA-upjFaHvw)

# %%
[link text](insert URL)
